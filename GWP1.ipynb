# %% [markdown]
# <a href="https://colab.research.google.com/github/KBryt/MSc_Financial_Engineering/blob/main/GWP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import zipfile
from google.colab import drive

drive.mount('/content/drive/')

zip_ref = zipfile.ZipFile("/content/drive/MyDrive/loan_data_2015.csv.zip", 'r')
zip_ref.extractall("/tmp")
zip_ref.close()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import zipfile
import io

# Replace 'your_file.zip' with the actual name of your zip file
with zipfile.ZipFile('/content/drive/MyDrive/loan_data_2015.csv.zip', 'r') as zip_ref:
    zip_ref.extractall('extracted_data')

# %%
import pandas as pd

# Load a CSV file from the extracted data
loan_data = pd.read_csv('extracted_data/loan_data_2015.csv')

# Now 'data' contains your data in a Pandas DataFrame
# Out:
# <ipython-input-20-409ecbb5f14a>:4: DtypeWarning: Columns (19,47,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('extracted_data/loan_data_2015.csv')

# %%
data.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  60516983   64537751      20000        20000            20000   36 months
# 1  60187139   64163931      11000        11000            11000   36 months
# 2  60356453   64333218       7000         7000             7000   36 months
# 3  59955769   63900496      10000        10000            10000   36 months
# 4  58703693   62544456       9550         9550             9550   36 months
#
#    int_rate  installment grade sub_grade  ... total_bal_il il_util  \
# 0     12.29       667.06     C        C1  ...          NaN     NaN
# 1     12.69       369.00     C        C2  ...          NaN     NaN
# 2      9.99       225.84     B        B3  ...          NaN     NaN
# 3     10.99       327.34     B        B4  ...          NaN     NaN
# 4     19.99       354.87     E        E4  ...          NaN     NaN
#
#   open_rv_12m  open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi  \
# ...

# %%
# Example: Load real estate market data for Scenario 2

real_estate_data = pd.read_csv('/content/drive/MyDrive/Real estate.csv')

# %%
real_estate_data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
# Data Exploration and Visualization

## Scenario 1: Credit Score Analysis
# Summary statistics of credit scores
credit_score_summary = credit_score_data['CreditScore'].describe()

# Histogram of credit scores
plt.figure(figsize=(8, 6))
sns.histplot(data=credit_score_data, x='CreditScore', bins=20, kde=True)
plt.title('Distribution of Credit Scores')
plt.xlabel('Credit Score')
plt.ylabel('Frequency')
plt.show()

# %%
## Scenario 2: Real Estate Market Analysis
# Summary statistics of home values
home_value_summary = real_estate_data['HomeValue'].describe()

# Line plot of home values over time
plt.figure(figsize=(10, 6))
sns.lineplot(data=real_estate_data, x='Date', y='HomeValue')
plt.title('Home Value Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Home Value')
plt.xticks(rotation=45)
plt.show()

# %%
# Correlation analysis (replace with your actual data)

# %%
# Example: Calculate correlation between credit scores and default rates
credit_score_data['DefaultRate'] = np.random.rand(len(credit_score_data))
correlation = credit_score_data['CreditScore'].corr(credit_score_data['DefaultRate'])

# %%
# Print correlation value
print(f'Correlation between Credit Score and Default Rate: {correlation:.2f}')

# %%
# Interpretation of results
# Explain how the data analysis and visualizations provide insights into the challenges
# Example: Higher credit scores may be associated with lower default rates, reducing financing risks.

# Conclusion
# Summarize the findings and how the data can help address the identified challenges

# Save the Jupyter notebook as a PDF (optional)
# You can use external tools like Jupyter nbconvert to save the notebook as a PDF.
# Make sure to include code execution results in the PDF.
