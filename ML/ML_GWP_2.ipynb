# %% [markdown]
# # **Student Group 6196**

# %% [markdown]
# YinHong
#
# Cyuzuzo Mutuye Tresor
#
# Bright Effah

# %% [markdown]
# # **Step 1:**

# %% [markdown]
# Our criticism focused more on the way the work was presented.The group feedback we received is shown below.
# 1. A 62% AI generation rate. Together, we will endeavor to get better and, before submitting our work, determine each members contribution AI creation rate to avoid marks on our hardwork results.
# 2. No Theft (Never). We'll keep making sure the material produced is unique and free of plagiarism.
# 3. Nothing to Calculate (No). We'll keep adding the computations to our Jupyter notebook.
# 4. Too brief of a report (No). We'll keep delivering a report that is more thorough.
# 5. There are no charts. Report with images rather than text (no). In the report, we'll still provide graphics and text.
# 6. Inadequate Reference List (No). We shall persist in furnishing an ample bibliography within our report.

# %% [markdown]
# # **Step 2:**

# %% [markdown]
# ## **Linear Discriminant Analysis**
# **Basics:**
#
# In the case of classification problems, supervised learning algorithms like LDA are applied. This approach to dimensionality reduction seeks a linear combination of features that separates the various classes of the dataset with maximum distance. LDA assumes that the covariance matrices of the different courses are identical and that data is Gaussian distributed. To deal better with class separation, LDA projects the original feature space into a lower-dimensional space.
#
# **Classification**
#
# The main categorization of LDAs is, however, their classification according to the type of tasks performed, such as;
#
# 1. Kernel Discriminant Analysis: This is the type of LDA in the kernel functions are involved in translating instances of input data to some higher-dimensional feature space.
# 2. Fisher's Linear Discriminant Analysis: This happens to be such an LDA variable that linearly combines the characteristics to maximize the between-class separation and to minimize the within-class variation.
# 3. Quadratic Discriminant Analysis: In this method, there can be a different covariance matrix for each class. In contrast, sparse discriminant analysis reduces the features by selecting only a subset of features.
# 4. Sparse discriminant analysis, on the other hand, reduces the features using feature selection.
# 5. Regularized DA: The methodology penalizes in the form of fines for overfitting the data.
#
#
# **Keywords:** Dimension reduction, regularization, Fischers LDA, Kernal DA, feature selection, covariance matrix.

# %% [markdown]
# ## **Support Vector Machines**
#
# **Basics:**
#
# Support vector machines is an approach to solving classification problems and has grown in popularity since its introduction in the 1990s. Like logistic regression, it is effective for linearly separable data, or data that can be separated by a linear boundary. However, there are hyperparameters that can be used to adjust the boundary to deal with non-linear data. This boundary is what we call the separating hyperplane.
#
#
# **Keywords:** Classification, Regression, Kernel Functions, Hyperplane

# %% [markdown]
# ## **Neural Networks**
# **Basics:**
#
# Neural Networks model is a supervised learning algorithm inspirated by human brain. It has many layers, each layer containing many neurons. Regression, and classification can use neural networks models, for example, it can do well in the fields of predictive analytics, picture identification, natural language processing, and so on. The results of learning are reflected in the weights of the model. However identifying patterns and links in the data that may be hard for people to see， although they can solve complicated issues.
#
# **Keywords:** neuron, layers, backpropagation, image recognition, natural language processing,predictive analytics

# %% [markdown]
# # **Step 3:**
#
# ## **Linear Discriminant Analysis**

# %% [markdown]
# ### **Advantages:**
#
# it can reduce the dimension of data well to improve the efficiency.
#
# When the data distribution is Gaussian, LDA has a better classification effect.
#
# LDA has fast calculation speed and is suitable for processing large-scale data sets.

# %%
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### **Disadvantages:**
# 1. **Linearity assumption:** LDA assumes that the decision boundary between classes is linear. If the underlying relationship in the time series data is non-linear, LDA may not perform well.
# 2. **Limited to classification:** LDA is primarily used for classification tasks and may not be suitable for other types of time series analysis, such as forecasting or regression.

# %% [markdown]
# ### **Equations:**
# Within-Class Scatter Matrix
# $$ S_W = \sum_{i=1}^{c} \sum_{x \in X_i} (x - \mu_i)(x - \mu_i)^T $$
#
# Between-class scatter matrix
# $$ S_B = \sum_{i=1}^{c} N_i (\mu_i - \mu)(\mu_i - \mu)^T $$
#
# Fisher's criterion
# $$ J(w) = \frac{w^T S_B w}{w^T S_W w} $$

# %% [markdown]
# ### **Features:**
# 1. **Works well with missing values:** LDA can handle missing values in the time series data by estimating the missing values based on the available data.
# 2. **Feature extraction**: LDA not only performs classification but also provides insights into the most discriminative features contributing to the separation between classes.

# %% [markdown]
# ### **Guide:**
#
# **Inputs:**
# - Time series data: A set of time series observations with corresponding class labels.
#
# **Outputs:**
# - Class predictions: Predicted class labels for new or unseen time series data.

# %% [markdown]
# ### **Hyperparameters:**
# 1. **Solver:** The solver algorithm used to compute the discriminant vectors (e.g., "svd" for singular value decomposition, "eigen" for eigenvalue decomposition).
# 2. **Shrinkage:** A parameter that controls the degree of shrinkage applied to covariance estimation.

# %% [markdown]
# ### **Illustration**
# This diagram provides a good illustration of how LDA works.
# By selecting the appropriate coordinates in the figure, the two types of data are very easy to distinguish in a new dimension, that is, the category is very sensitive to the new coordinates

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This picture is from https://zhuanlan.zhihu.com/p/33185052?from_voters_page=true

# %% [markdown]
# ### **Reference:**
# - Bagnall, A., Lines, J., Hills, J., & Bostrom, A. Time-series classification with COTE: the collective of transformation-based ensembles. *IEEE Transactions on Knowledge and Data Engineering* 27.9 (2015): 2522-2535.

# %% [markdown]
# ### **Keywords:**
# `Linear Discriminant Analysis`, `LDA`, `time series analysis`, `dimensionality reduction`, `class separation`, `Gaussian distribution`, `discriminant function`, `feature extraction`, `missing values`, `solver`, `shrinkage`.

# %% [markdown]
# ## **Support Vector Machine**
#
# ### **Advantages:**
#
# Support Vector Machines (SVM) offer several benefits when applied to time series analysis:
# 1. **Effective in high-dimensional spaces:** SVM can handle high-dimensional time series data and perform well even when the number of features is greater than the number of samples. This makes SVM suitable for analyzing time series with a large number of variables.
# 2. **Non-linear classification:** SVM can efficiently handle non-linear relationships in time series data by using kernel functions to map the data into a higher-dimensional space where linear separation is possible.
# 3. **Robust to overfitting:** SVM aims to find the optimal hyperplane that maximizes the margin between classes, which helps in generalizing well to unseen data and reduces the risk of overfitting.
# 4. **Versatile:** SVM can be used for both classification and regression tasks, making it applicable to various time series analysis problems.
#
# ### **Computation and Visualization(Part A)**

# %%
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  3 of 3 completed

# %% [markdown]
# ### **Computation and Visualization (Part 2)**

# %%
# Out:
#               importance      Variable
# MSCI KOREA      0.436123    MSCI KOREA
# MSCI DENMARK    0.219591  MSCI DENMARK
# MSCI FRANCE     0.196979   MSCI FRANCE
# MSCI NORWAY     0.147308   MSCI NORWAY

# %% [markdown]
# ### **Disadvantages:**
# 1. Sensitivity to parameter: SVM has several hyperparameters. We must  carefully tune them for good performance, such as the kernel type, regularization parameter, and kernel-specific parameters. Improper parameter selection can lead to a bad result.
# 2. The efficiency of processing large-scale datasets and high-dimensional datasets is low, and the training time is very long.

# %% [markdown]
# ### **Equations:**

# %% [markdown]
# Separating Hyperplane
#
# In a p-dimensional space, the equation of a hyperplane is:
#
# $\beta_{0} + \beta_{1}X_{1} + \beta_{2}X_{2} + \cdots +\beta_{p}X_{p} = 0$
#
#
# Maximal Margin Classifier
#
#
# $\sum_{j=1}^{p}\beta_{j}^{2} = 1$
#
# Using class labels yi as -1 or 1, a correct classification is given by:
#
# $y_{i} \left( \sum_{j=1}^{p}\beta_{j}X_{ij} + \beta_{0} \right) > 0$
#
# Misclassification is defined as:
#
# $y_{i} \left( \sum_{j=1}^{p}\beta_{j}X_{ij} + \beta_{0} \right) \leq 0$
#
# Inner Product and Kernels
#
# The inner product for two vectors a and b is:
#
# $\left<a, b\right> = \sum_{i=1}^{n} a_i b_i$
#
# For a new point X, a linear support vector machine is:
#
# $y(x) = \beta_0 + \sum_{i}^{n} \alpha_{i} \left<X, X_{i} \right>$
#
#
# The Gaussian Radial Basis Function kernel is given by:
#
# $K(X_{i}, X_{i'}) = \text{exp} \left( -\gamma ||X_{i} - X_{i'}||^2 \right)$

# %% [markdown]
# ### **Features:**
# 1. Works well with missing values: SVM can handle missing values by using appropriate imputation techniques or by considering missing values as a separate category.
# 2. Kernel functions: SVM allow the use of various kernel functions, such as linear, polynomial, radial basis function, and sigmoid, to handle non-linear relationships in time series data.

# %% [markdown]
# ### **Guide:**
#
# **Inputs:**
# - **Time series data:** A set of time series observations with corresponding class labels or regression targets.
#
# **Outputs:**
# - **Class predictions:** Predicted class labels for new or unseen time series data in classification tasks.
# - **Regression predictions:** Predicted numerical values for new or unseen time series data in regression tasks.

# %% [markdown]
# ### **Hyperparameters:**
# 1. **Kernel:** The type of kernel function used to transform the data into a higher-dimensional space (e.g., "linear," "poly," "rbf," "sigmoid").
# 2. **Regularization parameter (C):** Controls the trade-off between achieving a low training error and a small margin hyperplane.
# 3. **Kernel-specific parameters:** Some kernels, such as the polynomial kernel, may have additional parameters that need to be tuned, such as the degree of the polynomial or the width of the RBF kernel.

# %% [markdown]
# ### **Illustration**
# The following diagram is a good illustration of how SVM works.
# In a two-dimensional plane, it is obvious that samples of two colors are difficult to distinguish, but at high latitudes, samples can be separated by a simple plane.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - This figure is from multiple kernel learning alpaydin chapter 13.8

# %% [markdown]
# ### **Reference:**
# - Zhang, G. Peter, and Min Qi. Neural network forecasting for seasonal and trend time series. *European journal of operational research* 160.2 (2005): 501-514.

# %% [markdown]
# ### **Keywords:**
# `Support Vector Machines`, `SVM`, `time series analysis`, `high-dimensional spaces`, `non-linear classification`, `overfitting`, `parameter selection`, `computation`, `decision function`, `missing values`, `kernel functions`, `guide`, `hyperparameters`.

# %% [markdown]
# ## **Neural Network**
#
# ### **Advantages:**
#
# 1. It can be very flexible, because it can model complex relationship, such as non-linear relationship.
# 2.  It can auomatically extract featrue.
# 3. Scalling law: The bigger the model, the more likely it is to exhibit intelligence.
#
# 4. Support multimodality

# %%
# Out:
# /content
#             CES0500000003  MANEMP  PCUOMFGOMFG   DGORDER    AMTMNO  Adj Close
# Date
# 2021-12-01          31.38   12555      226.470  256464.0  508780.0    36226.0
# 2022-01-01          31.56   12581      231.495  264356.0  520531.0    34997.0
# 2022-02-01          31.60   12631      237.245  262494.0  522118.0    33840.0
# 2022-03-01          31.75   12689      245.404  264258.0  531412.0    34618.0
# 2022-04-01          31.86   12750      249.560  265376.0  534971.0    32882.0
#             CES0500000003    MANEMP  PCUOMFGOMFG   DGORDER    AMTMNO  \
# Date
# 2006-04-01       0.010152  1.000000     0.023266  0.432924  0.369057
# 2006-05-01       0.007614  0.991795     0.037014  0.440572  0.390308
# 2006-06-01       0.015228  0.995362     0.047589  0.475165  0.407705
# 2006-07-01       0.021997  0.986443     0.046531  0.400060  0.361270
# 2006-08-01       0.023689  0.976097     0.050761  0.406331  0.369645
#
#             Adj Close
# Date
# 2006-04-01   0.020724
# ...

# %% [markdown]
# ### **Disadvantages:**
# - Neural networks is complexity.  They always have many parameters.
# - We may can't understand their meanings in real world,ie low interpretability.
# - It is easily to overfit and cost too long time and energy because too many parameters.

# %% [markdown]
# ### **Equations:**
# The general equation for a feedforward Neural Network can be represented as:
#
# $$
# \begin{equation}
# X_{1} = f(X_{0} w_{0}+b_{0}),
# \tag{1}
# \end{equation}
# $$
#
#
# $$
# \begin{equation}
# Y = f(X_{1} w_{1}+b_{1})=f(f(X_{0} w_0 +b_{0}) w_1+b_{1}),
# \tag{2}
# \end{equation}
# $$
#
# where `x` is the input vector, `W` is the weight matrix, `b` is the bias vector, `f` is the activation function, and `y` is the output vector.
#
# Sigmoid activation function:
# $$
# \begin{equation}
# σ(x) = \frac{1}{1+e^{-x}}
# \end{equation}
# $$
#  gradient
#  $$
# \begin{equation}
# \text{Gradient} = \frac{\text{change in output}}{\text{change in input}}
# \end{equation}
# $$

# %% [markdown]
# ### **Features:**
# 1. **Handling missing values:** Neural Networks works well with missing values
# 2. Generalization: if it is well tunned, neural networks can generalize well to unseen data.

# %% [markdown]
# ### **Guide:**
# **Inputs:**
#  Features or predictors
#
# **Outputs:**
#  Predicted values, such as Class predictions, Regression predictions,
# Time series forecasting

# %% [markdown]
# ### **Hyperparameters:**
# 1. **Number of layers:** number of hidden layers
# 2. **Number of neurons:** number of neurons in each hidden layer.
# 3. **Activation functions:** choice of activation functions for each neuron such as ReLU, sigmoid etc.
# 4. **Learning rate:** shows the rate at which the model updates its weights during training.
# 5. **Batch size:** indicate the number of samples used in each iteration for training.

# %% [markdown]
# ### **Illustrator**
# The following is a schematic of a neural network made up of four layers, each with multiple neurons. The activation value of each neuron is weighted by the activation value of the previous layer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - This image is from youtube video of https://www.youtube.com/c/3blue1brown

# %% [markdown]
# ### **Reference:**
# - Tsantekidis, A., Passalis, N., Tefas, A., & Kanniainen, J. Forecasting stock prices from the limit order book using convolutional neural networks. *2017 IEEE 19th conference on business informatics (CBI)*. Vol. 1. IEEE, 2017.

# %% [markdown]
# ### **Keywords:**
# `Neural Networks`, `time series analysis`, `non-linear modeling`, `feature learning`, `large datasets`, `architecture flexibility`, `computation`, `feedforward Neural Network`, `missing values`, `sequential modeling`, `parallel processing`, `guide`, `hyperparameters`.

# %% [markdown]
# # **Step 4: Technical Section: Hyperparameter Tuning**

# %% [markdown]
# One of the essential steps that go into bettering the performance of ML models has to do with hyperparameter tuning. In other words, hyperparameters are those that are predefined and can't be learned from data-driven analysis. They regulate the model's behavior and complexity, and making adjustments to them can have a big effect on how well the model performs when applied to time series data. This section will cover the process of fine-tuning hyperparameters and include instances of hyperparameters used for neural networks, support vector machines (SVM), and linear discriminant analysis (LDA).
#
# **Hyperparameter Tuning Process:**
# 1. Describe the area under search: Ascertain the range or range of values that are possible for every hyperparameter that you wish to adjust.
#
# 2. Choose a search approach: Select a technique, such as grid search, random search, or Bayesian optimization, to investigate the hyperparameter search space.
# 3. Evaluation Metric: Define some metric by which the model is to be evaluated for its performance about different hyperparameter settings applied. Depending on the task, this might be mean squared error, recall, accuracy, precision, or any other relevant statistic.
#
# 4. Cross-validation: Since the data is time series, the time-series data will be split into training and validation sets. Walk-forward validation or rolling-window cross-validation can ensure that a realistic assessment of model performance does occur during the evaluation.
# 5. Hyperparameter Tuning: Run the chosen search algorithm to discover the best combination of hyperparameters for optimizing the assessment metric. Investigate model performance on the validation set for different settings of the hyperparameters.
#
# 6. Model selection: According to your evaluation metric, choose the best-performing model on the validation set.
# 7. Examine on a test set: Following the selection of the optimal model, determine the model's generalization capabilities by evaluating its performance on a separate test set.
#
# Examples of Hyperparameters for Time Series Models:
#
# 1. **Linear Discriminant Analysis (LDA):**
# - **Solver:** There are three options: 'eigen' (Eigenvalue Decomposition), 'lsqr' (Least Squares), and'svd' (Singular Value Decomposition).
# - **Shrinkage:** The covariance matrix is estimated using the shrinkage parameter. It regulates the ratio of a priori knowledge to the sample covariance matrix.
# - **n_components:** The quantity of discriminant components to retain, n_components. It establishes how many dimensions the modified feature space has.
#
# 2. **Support Vector Machines (SVM):**
# - **Kernel:** The kernel function can be linear, polynomial, sigmoid, or the radial basis function (RBF). Hyperparameters are unique to each kernel.
# - **C:** Achieving a low training error and a low complexity model are traded off, and this is managed by the regularization parameter C.
# - **Gamma:** The 'rbf', 'poly', and'sigmoid' kernel coefficients. It determines the impact of every training case and influences the decision boundary's degree of flexibility.
#
# 3. **Neural Networks:**
# - **Number of layers:** The count of concealed layers within the architecture of a neural network.
# - **Number of neurons:** The quantity of neurons found in every hidden layer.
# - **Learning rate:** The speed at which weights are updated by the model while it is being trained.
# - **Batch size:** The quantity of samples used in a training cycle.
# - **Activation functions:**  The sigmoid, tanh, or ReLU activation function that each neuron chooses to use.
# - **Regularization parameters:** The hyperparameters that regulate regularization methods such as $L_1/L_2$ regularization or dropout regularization.
#
# **Note:** The particular hyperparameters and their ranges may vary based on the library and implementation (e.g., scikit-learn, TensorFlow, PyTorch). For comprehensive information about hyperparameters, it is crucial to refer to the documentation of the particular library.
#
# You can determine the ideal configuration that maximizes the model's performance on your time series data by methodically adjusting these hyperparameters.
#
# **Keywords:** `hyperparameter tuning`, `search space`, `search strategy`, `evaluation metric`, `cross-validation`, `linear discriminant analysis`, `support vector machines`, `neural networks`, `solver`, `shrinkage`, `n_components`, `kernel`, `C`, `gamma`, `number of layers`, `number of neurons`, `learning rate`, `batch size`, `activation functions`, `regularization parameters`.

# %% [markdown]
# # **Step 5: Marketing Alpha: Harnessing the Power of ML Techniques**

# %% [markdown]
# ## **Introduction:**
#
# Considering strong tools for evaluating time series data, machine learning (ML) approaches have completely changed the finance industry. We will examine the use of three sophisticated machine learning models—Linear Discriminant Analysis (LDA), Support Vector Machines (SVM), and Neural Networks—to attain marketing alpha in this section. Understanding these models' benefits and features will enable us to take advantage of them and use them to make more intelligent and successful investment decisions.
#
# ## **Advantages and Features:**
#
# ### 1. **Linear Discriminant Analysis (LDA):**
#
# #### **Advantages:**
# - LDA is a dimensionality reduction method that finds the most discriminative characteristics in a dataset and effectively divides it into classes.
# - It can handle scenarios when there is a significant difference in the distribution of data across classes and it is predicated on multivariate normality.
# - In order to maximize class separability, LDA generates linear feature combinations that yield findings that are easy to understand.
#
# #### **Features:**
# - Performs well with continuous or categorical dependent variables.
# - Manages multicollinearity, which qualifies it for correlated feature datasets.
#
# - Offers perceptions into the proportional significance of characteristics throughout the classification process.
#
# #### **Reference:**
# Fisher, Ronald A. The use of multiple measurements in taxonomic problems. *Annals of eugenics* 7.2 (1936): 179-188.
#
# ### 2. **Support Vector Machines (SVM):**
#
# #### **Advantages:**
# - SVM functions well in high-dimensional spaces and can manage complicated decision boundaries.
#
# - It works well with datasets that are both linearly and nonlinearly separable.
#
# - SVM is less likely to overfit when regularization techniques are used.
#
# #### **Features:**
# - Able to manage problems involving both regression and classification.
# - Performs effectively with datasets that are tiny to medium-sized.
# - Can incorporate different kernel functions to capture nonlinear relationships.
#
# #### **Reference:**
#
# Cortes, Corinna, and Vladimir Vapnik. Support-vector networks. *Machine learning* 20 (1995): 273-297.
#
# ### 3. **Neural Networks:**
# #### **Advantages:**
# - Neural Networks can capture complex patterns and nonlinear relationships in time series data.
# - They are highly flexible and can learn from large amounts of data, adapting to changing market conditions.
# - Neural Networks can automatically extract relevant features from raw data, reducing the need for extensive feature engineering.
#
# #### **Features:**
# - Suitable for handling both univariate and multivariate time series data.
# - Can model both short-term and long-term dependencies in the data.
# - Allows for the incorporation of various activation functions and network architectures.
#
# #### **Reference:**
#
# Hochreiter, Sepp, and Jürgen Schmidhuber. Long short-term memory. *Neural computation* 9.8 (1997): 1735-1780.
#
# ### **Integration of ML Techniques for Marketing Alpha:**
# The potential for marketing alpha in finance can be unlocked through the integration of LDA, SVM, and neural networks. To enable customized marketing strategies, LDA, for instance, can be used to determine which attributes are most important in distinguishing between distinct client segments. SVM can help with pattern recognition and market forecasting using historical data, which can help with well-informed investment decisions. Neural Networks can be used to analyze complicated and dynamic data patterns in order to forecast future market trends and optimize marketing strategies.
#
# Financial professionals may improve their alpha-generating capabilities and obtain a competitive advantage in the market by utilizing the benefits and features of these machine learning techniques. To guarantee the models’ efficacy and dependability, it is necessary to take into account the unique features of the data, adjust the hyperparameters meticulously, and check the models’ performance on untested data.
#
# ### **Conclusion:**
# In the finance sector, there are intriguing opportunities for reaching marketing alpha through the integration of advanced machine learning techniques including support vector machines, neural networks, and linear discriminant analysis. Financial professionals can leverage machine learning (ML) to improve marketing tactics, make more accurate predictions, and produce higher investment returns by comprehending the benefits and features of these models and implementing them thoughtfully and methodically accross the sector.
#
# ### **Keywords:**
#
# `marketing alpha`, `Linear Discriminant Analysis`, `Support Vector Machines`, `Neural Networks, advantages`, `features`, `integration`, `finance`, `investment decisions`, `targeted marketing`, `market movements`, `forecasting`, `optimization`.
#
# ###**References:**
#
# 1. Fisher, Ronald A. The use of multiple measurements in taxonomic problems. *Annals of eugenics* 7.2 (1936): 179-188.
# 2. Cortes, Corinna, and Vladimir Vapnik. Support-vector networks. *Machine learning* 20 (1995): 273-297.
# 3. Hochreiter, Sepp, and Jürgen Schmidhuber. Long short-term memory. *Neural computation* 9.8 (1997): 1735-1780.

# %% [markdown]
# #**Step 6: Learn More**

# %% [markdown]
# Here are the references for more learning:
#
# 1. Blanco-Oliver, A., R. Pino-Mejías, and J. Lara-Rubio. "Modeling the Financial Distress of Microenterprise StartUps Using Support Vector Machines: A Case Study. *Revista Innovar Journal*, vol. 24, 2014, pp. 153-168.
#
# 2. Burgess, Paul L., et al. Applications of Multiple Linear Discriminant Analysis to the Labor Market Experience of UI Claimants. *U.S. Dept. of Labor, Manpower Administration, Unemployment Insurance Service*, 1974.
#
# 3. Goodfellow, Ian, et al. Deep Learning. Vol. 1, *MIT Press*, 2016.
#
# 4. LeCun, Yann, et al. Deep learning. *Nature*, vol. 521, no. 7553, 2015, pp. 436-444.
#
# 5. Lin, Yuling, et al. An SVM-Based Approach for Stock Market Trend Prediction. *The 2013 International Joint Conference on Neural Networks (IJCNN)*, 2013, pp. 1-7.
#
# 6. Nokeri, Tshepo Chris. *Data Science Revealed: With Feature Engineering, Data Visualization, Pipeline Development, and Hyperparameter Tuning.* Apress, 2021.
#
# 7. Raschka, Sebastian, and Vahid Mirjalili. *Python Machine Learning: Machine Learning and Deep Learning with Python, *scikit-learn, and TensorFlow 2. 3rd ed.*, Packt Publishing, 2019.
#
# 8. Schmidhuber, Jürgen. "Deep learning in neural networks: An overview." Neural Networks, vol. 61, 2015, pp. 85-117.
#
# 9. Wu, Yufei, and Guan Yu. Weighted Linear Programming Discriminant Analysis For high-dimensional Binary Classification. *Statistical Analysis and Data Mining, vol. 13*, no. 5, 2020, pp. 437-450, https://doi.org/10.1002/sam.11473.
#
# 10. Zhang, Zhoubing, Mert Sabuncu, and Thomas M. Deserno. Deep learning in medical imaging: A review. *Physics in Medicine & Biology, vol. 63*, no. 13, 2018, p. 13TR01.

# %% [markdown]
# # **Step 7: Comparing Models**

# %% [markdown]
# Below are the comparisons of the models indicated in the following:
# - **Handles Missing Data:**
#   - LDA: Manages effectively
#   - SVM: Implementation-dependent; often handles well.
#   - NN: Depending on how it's implemented, but in general, it works well.
#
# - **Handles the High-Dimensional Data:**
#   - Large datasets are well-suited for LDA.
#   - SVM: Because SVM with SGD is an efficient algorithm, it handles large datasets quite well.
#
#   - NN: Has the capacity to manage big datasets, although it can be costly to compute.
#
# - **Handles Non-Linear Relationships:**
#   - LDA: Has limited resilience to non-linearity.
#
#   - SVM: Originally, this method did a good job of handling non-linearity, particularly when kernel functions are involved.
#
#   - NN: Is fairly adept at handling non-linearity, particularly when dealing with non-linear activation functions such as ReLU.
#
# - **Handles Overfitting:**
#   - LDA: Is resistant to overfitting, particularly when regularization methods are used.
#   - SVM: Effectively manages overfitting, particularly when the regularization parameter (C) is adjusted.
#   - NN: prone to overfitting; dropout or weight decay regularization methods are needed.
